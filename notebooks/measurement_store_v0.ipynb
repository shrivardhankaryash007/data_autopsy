# %% [markdown]
# # MeasurementStore v0
#
# Minimal notebook stub for experimenting with the in-memory store.

# %%
from data_autopsy.measurement_store import MeasurementStore

store = MeasurementStore()
store.record("latency_ms", 120.5, tags={"host": "api-1"})
store.list()
# Out:
# [Measurement(metric='latency_ms', value=120.5, timestamp=datetime.datetime(2026, 1, 21, 9, 24, 40, 497764, tzinfo=datetime.timezone.utc), tags={'host': 'api-1'})]
